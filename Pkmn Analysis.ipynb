# %%
import pandas
table = pandas.read_csv('./pkmn_dataset.csv')

# %%
# Who are the 10 fastest Pokemon?
table.sort_values('Speed', ascending=False).head(10)
# Out:
#      Number                          Name         Types  Total  HP  Attack  \
# 449     386          Deoxys - Speed Forme       Psychic    600  50      95
# 333     291                       Ninjask    Bug Flying    456  61      90
# 900     795                     Pheromosa  Bug Fighting    570  71     137
# 447     386         Deoxys - Attack Forme       Psychic    600  50     180
# 446     386         Deoxys - Normal Forme       Psychic    600  50     150
# 82       65      Alakazam - Mega Alakazam       Psychic    590  55      50
# 172     142  Aerodactyl - Mega Aerodactyl   Rock Flying    615  80     135
# 19       15      Beedrill - Mega Beedrill    Bug Poison    495  65     150
# 696     617                      Accelgor           Bug    495  80      70
# 293     254      Sceptile - Mega Sceptile  Grass Dragon    630  70     110
#
#      Defense  Special Attack  Special Defense  Speed
# 449       90              95               90    180
# ...

# %%
# Who are the 10 fastest Bug-type pokemon?
bug_types = table[table['Types'].str.contains('Bug')]
fastest_bug_types = bug_types.sort_values('Speed', ascending=False).head(10)
# Out:
#      Number                      Name         Types  Total  HP  Attack  \
# 333     291                   Ninjask    Bug Flying    456  61      90
# 900     795                 Pheromosa  Bug Fighting    570  71     137
# 19       15  Beedrill - Mega Beedrill    Bug Poison    495  65     150
# 696     617                  Accelgor           Bug    495  80      70
# 845     743                  Ribombee     Bug Fairy    464  60      55
# 623     545                 Scolipede    Bug Poison    485  60     100
# 711     632                    Durant     Bug Steel    484  58     109
# 675     596                Galvantula  Bug Electric    472  70      77
# 150     123                   Scyther    Bug Flying    500  70     110
# 155     127      Pinsir - Mega Pinsir    Bug Flying    600  65     155
#
#      Defense  Special Attack  Special Defense  Speed
# 333       45              50               50    160
# 900       37             137               37    151
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# How does the speed of Bug and Fairy compare?
fairy_types = table[table['Types'].str.contains('Fairy')]

#TODO - Need to figure this out

#fairy_means = fairy_types.mean()
#bug_means = bug_types.mean().plot.barh()
#fairy_means
#bug_means
                    
#table.groupby('Types')['Speed'].sum().reset_index()

#chart = bug_types.head(5)['Speed'].plot.barh().set_yticklabels(bug_types['Name'])
